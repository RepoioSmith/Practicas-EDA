# %%
# !pip install pgmpy
import pandas as pd
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.inference import VariableElimination

df = pd.read_csv('wbes_sintetico.csv').dropna()

promedio_ventas = df['sales_annual_usd'].mean()
df['successful'] = (df['sales_annual_usd'] > promedio_ventas).astype(int)

variables_red = ['successful', 'training', 'financing_obtained', 'competition_level', 'exporter']
df_bayes = df[variables_red].astype(int)

modelo_bayes = BayesianNetwork([
    ('financing_obtained', 'successful'),
    ('training', 'successful'),
    ('competition_level', 'successful'),
    ('exporter', 'successful')
])

modelo_bayes.fit(df_bayes, estimator=MaximumLikelihoodEstimator)

inferencia = VariableElimination(modelo_bayes)
probabilidad = inferencia.query(variables=['successful'], evidence={'training': 1, 'financing_obtained': 1})

print(probabilidad)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # !pip install pgmpy
#       2 import pandas as pd
# ----> 3 from pgmpy.models import BayesianNetwork
#       4 from pgmpy.estimators import MaximumLikelihoodEstimator
#       5 from pgmpy.inference import VariableElimination
#
# ModuleNotFoundError: No module named 'pgmpy'
